# %%
import os
import pandas as pd
df = pd.read_excel('New Microsoft Excel Worksheet.xlsx')
dir_name_list = df['Box No.'].tolist()
dir_name_list
# Out:
# ['S.169499.1.LI',
#  'S.173478.39.LI',
#  'S.173801.1.LI',
#  'S.174681.8ARP',
#  'S.175032.4ARP',
#  'S.176389.1ARP',
#  'S.177019.1.LI',
#  'S.177028.1.LI',
#  'S.177484.4ARP',
#  'S.177493.26ARP',
#  'S.177495.2ARP',
#  'S.177495.26ARP',
#  'S.177717.1.LI',
#  'S.178110.15ARP',
#  'S.178110.16ARP',
#  'S.178110.17ARP',
#  'S.178110.18ARP',
#  'S.178110.1ARP',
#  'S.178110.2ARP',
#  'S.178110.4ARP',
#  'S.178110.7ARP',
#  'S.178110.8ARP',
#  'S.178116.11ARP',
#  'S.178116.4ARP',
#  'S.178117.1ARP',
#  'S.178117.3ARP',
#  'S.178117.4ARP',
#  'S.178140.10ARP',
#  'S.178140.11ARP',
#  'S.178140.17ARP',
#  'S.178364.1.BA',
#  'S.178367.1.BA',
#  'S.178676.3ARP',
#  'S.178677.2ARP',
#  'S.178677.3ARP',
#  'S.178677.4ARP',
#  'S.178976.1.LI',
#  'S.179124.4ARP',
#  'S.179742.1.LI',
#  'S.179790.1.LI',
#  'S.179880.1.LI',
#  'S.179881.1.LI',
#  'S.179958.1ARP',
#  'S.180116.1.LI',
#  'S.180219.1.LI',
#  'S.180323.1.LI',
#  'S.180410.1ARP',
#  'S.180526.11ARP',
#  'S.180526.1ARP',
# ...

# %%
for i in dir_name_list:
    if not os.path.exists(i):
        os.makedirs(i)
        print(i+' done')
    else:
        print('appear duplication')
# Out:
# S.169499.1.LIdone
# S.173478.39.LIdone
# S.173801.1.LIdone
# S.174681.8ARPdone
# S.175032.4ARPdone
# S.176389.1ARPdone
# S.177019.1.LIdone
# S.177028.1.LIdone
# S.177484.4ARPdone
# S.177493.26ARPdone
# S.177495.2ARPdone
# S.177495.26ARPdone
# S.177717.1.LIdone
# S.178110.15ARPdone
# S.178110.16ARPdone
# S.178110.17ARPdone
# S.178110.18ARPdone
# S.178110.1ARPdone
# S.178110.2ARPdone
# S.178110.4ARPdone
# S.178110.7ARPdone
# S.178110.8ARPdone
# S.178116.11ARPdone
# S.178116.4ARPdone
# S.178117.1ARPdone
# S.178117.3ARPdone
# S.178117.4ARPdone
# S.178140.10ARPdone
# S.178140.11ARPdone
# S.178140.17ARPdone
# S.178364.1.BAdone
# S.178367.1.BAdone
# S.178676.3ARPdone
# S.178677.2ARPdone
# S.178677.3ARPdone
# S.178677.4ARPdone
# S.178976.1.LIdone
# S.179124.4ARPdone
# S.179742.1.LIdone
# S.179790.1.LIdone
# S.179880.1.LIdone
# S.179881.1.LIdone
# S.179958.1ARPdone
# S.180116.1.LIdone
# S.180219.1.LIdone
# S.180323.1.LIdone
# S.180410.1ARPdone
# S.180526.11ARPdone
# S.180526.1ARPdone
# ...
